# %%
from db_utils import DB
import pandas as pd
import numpy as np

# %%
import datetime as dt
import time

# %%
df = pd.read_csv('Fires.csv')
# Out:
# D:\Users\hvard\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (8,10,11,12,13,14,15,16,17,18,35,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.drop('Unnamed: 38', axis =1)

# %%
columns = df.columns

# %%
columns
# Out:
# Index(['OBJECTID', 'FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE', 'SOURCE_SYSTEM',
#        'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID',
#        'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT',
#        'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID',
#        'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'FIRE_NAME',
#        'ICS_209_INCIDENT_NUMBER', 'ICS_209_NAME', 'MTBS_ID', 'MTBS_FIRE_NAME',
#        'COMPLEX_NAME', 'FIRE_YEAR', 'DISCOVERY_DATE', 'DISCOVERY_DOY',
#        'DISCOVERY_TIME', 'STAT_CAUSE_CODE', 'STAT_CAUSE_DESCR', 'CONT_DATE',
#        'CONT_DOY', 'CONT_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE',
#        'LONGITUDE', 'OWNER_CODE', 'OWNER_DESCR', 'STATE', 'COUNTY',
#        'FIPS_CODE', 'FIPS_NAME'],
#       dtype='object')

# %%
new_cols = [col.lower() for col in columns]

# %%
new_cols
# Out:
# ['objectid',
#  'fod_id',
#  'fpa_id',
#  'source_system_type',
#  'source_system',
#  'nwcg_reporting_agency',
#  'nwcg_reporting_unit_id',
#  'nwcg_reporting_unit_name',
#  'source_reporting_unit',
#  'source_reporting_unit_name',
#  'local_fire_report_id',
#  'local_incident_id',
#  'fire_code',
#  'fire_name',
#  'ics_209_incident_number',
#  'ics_209_name',
#  'mtbs_id',
#  'mtbs_fire_name',
#  'complex_name',
#  'fire_year',
#  'discovery_date',
#  'discovery_doy',
#  'discovery_time',
#  'stat_cause_code',
#  'stat_cause_descr',
#  'cont_date',
#  'cont_doy',
#  'cont_time',
#  'fire_size',
#  'fire_size_class',
#  'latitude',
#  'longitude',
#  'owner_code',
#  'owner_descr',
#  'state',
#  'county',
#  'fips_code',
#  'fips_name']

# %%
db = DB('fpa_fod')
# Out:
# 2019-11-06 15:40:21,581 - INFO - db_utils.py @39 : __init__() - Creating engine for database `fpa_fod`...
# 2019-11-06 15:40:21,582 - DEBUG - db_utils.py @40 : __init__() - Databse config: mysql://root:root@127.0.0.1:3306/fpa_fod?charset=utf8
# 2019-11-06 15:40:21,617 - INFO - db_utils.py @42 : __init__() - Databse engine created.

# %%
df.columns
# Out:
# Index(['objectid', 'fod_id', 'fpa_id', 'source_system_type', 'source_system',
#        'nwcg_reporting_agency', 'nwcg_reporting_unit_id',
#        'nwcg_reporting_unit_name', 'source_reporting_unit',
#        'source_reporting_unit_name', 'local_fire_report_id',
#        'local_incident_id', 'fire_code', 'fire_name',
#        'ics_209_incident_number', 'ics_209_name', 'mtbs_id', 'mtbs_fire_name',
#        'complex_name', 'fire_year', 'discovery_date', 'discovery_doy',
#        'discovery_time', 'stat_cause_code', 'stat_cause_descr', 'cont_date',
#        'cont_doy', 'cont_time', 'fire_size', 'fire_size_class', 'latitude',
#        'longitude', 'owner_code', 'owner_descr', 'state', 'county',
#        'fips_code', 'fips_name'],
#       dtype='object')

# %%
df.rename(columns={'discovery_date':'discovery_date_1', 'cont_date':'cont_date_1'}, inplace=True)

# %%
df.dtypes
# Out:
# objectid                        int64
# fod_id                          int64
# fpa_id                         object
# source_system_type             object
# source_system                  object
# nwcg_reporting_agency          object
# nwcg_reporting_unit_id         object
# nwcg_reporting_unit_name       object
# source_reporting_unit          object
# source_reporting_unit_name     object
# local_fire_report_id           object
# local_incident_id              object
# fire_code                      object
# fire_name                      object
# ics_209_incident_number        object
# ics_209_name                   object
# mtbs_id                        object
# mtbs_fire_name                 object
# complex_name                   object
# fire_year                       int64
# discovery_date_1              float64
# discovery_doy                   int64
# discovery_time                float64
# stat_cause_code                 int64
# stat_cause_descr               object
# ...

# %%
def table_builder(columns):
    res = ''
    for col in columns:
        res += col
        res += ' TEXT'
        res += ' NULL, '
    print(res)

# %%
table_builder(new_cols)
# Out:
# objectid TEXT NULL, fod_id TEXT NULL, fpa_id TEXT NULL, source_system_type TEXT NULL, source_system TEXT NULL, nwcg_reporting_agency TEXT NULL, nwcg_reporting_unit_id TEXT NULL, nwcg_reporting_unit_name TEXT NULL, source_reporting_unit TEXT NULL, source_reporting_unit_name TEXT NULL, local_fire_report_id TEXT NULL, local_incident_id TEXT NULL, fire_code TEXT NULL, fire_name TEXT NULL, ics_209_incident_number TEXT NULL, ics_209_name TEXT NULL, mtbs_id TEXT NULL, mtbs_fire_name TEXT NULL, complex_name TEXT NULL, fire_year TEXT NULL, discovery_date TEXT NULL, discovery_doy TEXT NULL, discovery_time TEXT NULL, stat_cause_code TEXT NULL, stat_cause_descr TEXT NULL, cont_date TEXT NULL, cont_doy TEXT NULL, cont_time TEXT NULL, fire_size TEXT NULL, fire_size_class TEXT NULL, latitude TEXT NULL, longitude TEXT NULL, owner_code TEXT NULL, owner_descr TEXT NULL, state TEXT NULL, county TEXT NULL, fips_code TEXT NULL, fips_name TEXT NULL,

# %%
db.insert(df, 'fires', if_exists='append', index=False, chunksize=1000)
# Out:
# 2019-11-05 18:29:55,925 - INFO - db_utils.py @122 : insert() - Inserting dataframe into `fires`...
# 2019-11-05 18:29:56,338 - DEBUG - db_utils.py @123 : insert() - Data:
#          OBJECTID   FOD_ID         FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0               1        1     FS-1418826                FED   FS-FIRESTAT
# 1               2        2     FS-1418827                FED   FS-FIRESTAT
# 2               3        3     FS-1418835                FED   FS-FIRESTAT
# 3               4        4     FS-1418845                FED   FS-FIRESTAT
# 4               5        5     FS-1418847                FED   FS-FIRESTAT
# 5               6        6     FS-1418849                FED   FS-FIRESTAT
# 6               7        7     FS-1418851                FED   FS-FIRESTAT
# 7               8        8     FS-1418854                FED   FS-FIRESTAT
# 8               9        9     FS-1418856                FED   FS-FIRESTAT
# ...

# %%
df.shape
# Out:
# (1048575, 38)

# %%
df.size
# Out:
# 39845850

# %%
def f(x):
    return (dt.datetime(x['fire_year'],1,1)+dt.timedelta(x['discovery_doy']-1)).strftime('%Y-%m-%d')

# %%
start = time.time()
a = df.apply(f, axis=1)
print(f'Time taken = {time.time()-start:.2f} secs')
# Out:
# Time taken = 43.32 secs

# %%
df['discovery_date'] = a

# %%
cols = list(df.columns)

# %%
cols
# Out:
# Index(['objectid', 'fod_id', 'fpa_id', 'source_system_type', 'source_system',
#        'nwcg_reporting_agency', 'nwcg_reporting_unit_id',
#        'nwcg_reporting_unit_name', 'source_reporting_unit',
#        'source_reporting_unit_name', 'local_fire_report_id',
#        'local_incident_id', 'fire_code', 'fire_name',
#        'ics_209_incident_number', 'ics_209_name', 'mtbs_id', 'mtbs_fire_name',
#        'complex_name', 'fire_year', 'discovery_date_1', 'discovery_doy',
#        'discovery_time', 'stat_cause_code', 'stat_cause_descr', 'cont_date_1',
#        'cont_doy', 'cont_time', 'fire_size', 'fire_size_class', 'latitude',
#        'longitude', 'owner_code', 'owner_descr', 'state', 'county',
#        'fips_code', 'fips_name', 'discovery_date'],
#       dtype='object')

# %%
new = cols[:20] + [cols[-1]] + cols[21:-1]

# %%
new
# Out:
# ['objectid',
#  'fod_id',
#  'fpa_id',
#  'source_system_type',
#  'source_system',
#  'nwcg_reporting_agency',
#  'nwcg_reporting_unit_id',
#  'nwcg_reporting_unit_name',
#  'source_reporting_unit',
#  'source_reporting_unit_name',
#  'local_fire_report_id',
#  'local_incident_id',
#  'fire_code',
#  'fire_name',
#  'ics_209_incident_number',
#  'ics_209_name',
#  'mtbs_id',
#  'mtbs_fire_name',
#  'complex_name',
#  'fire_year',
#  'discovery_date',
#  'discovery_doy',
#  'discovery_time',
#  'stat_cause_code',
#  'stat_cause_descr',
#  'cont_date_1',
#  'cont_doy',
#  'cont_time',
#  'fire_size',
#  'fire_size_class',
#  'latitude',
#  'longitude',
#  'owner_code',
#  'owner_descr',
#  'state',
#  'county',
#  'fips_code',
#  'fips_name']

# %%
df_new = df[new]

# %%
df_new.discovery_date
# Out:
# 0          2005-02-02
# 1          2004-05-12
# 2          2004-05-31
# 3          2004-06-28
# 4          2004-06-28
# 5          2004-06-30
# 6          2004-07-01
# 7          2005-03-08
# 8          2005-03-15
# 9          2004-07-01
# 10         2004-07-02
# 11         2004-07-02
# 12         2004-09-03
# 13         2004-09-28
# 14         2004-10-03
# 15         2004-10-03
# 16         2004-10-06
# 17         2004-10-13
# 18         2004-11-20
# 19         2004-06-04
# 20         2004-06-19
# 21         2004-06-21
# 22         2004-06-25
# 23         2004-07-01
# 24         2004-07-01
# 25         2004-07-20
# 26         2004-03-18
# 27         2004-08-05
# 28         2004-03-18
# 29         2004-05-11
#               ...
# 1048545    2002-04-17
# 1048546    2002-04-17
# 1048547    2002-04-19
# 1048548    2002-04-19
# 1048549    2002-04-19
# 1048550    2002-04-22
# 1048551    2002-04-22
# 1048552    2002-04-23
# 1048553    2002-04-23
# 1048554    2002-04-23
# ...

# %%
cols[21:-1]
# Out:
# ['discovery_doy',
#  'discovery_time',
#  'stat_cause_code',
#  'stat_cause_descr',
#  'cont_date_1',
#  'cont_doy',
#  'cont_time',
#  'fire_size',
#  'fire_size_class',
#  'latitude',
#  'longitude',
#  'owner_code',
#  'owner_descr',
#  'state',
#  'county',
#  'fips_code',
#  'fips_name']

# %%
cols[21:]
# Out:
# ['discovery_doy',
#  'discovery_time',
#  'stat_cause_code',
#  'stat_cause_descr',
#  'cont_date_1',
#  'cont_doy',
#  'cont_time',
#  'fire_size',
#  'fire_size_class',
#  'latitude',
#  'longitude',
#  'owner_code',
#  'owner_descr',
#  'state',
#  'county',
#  'fips_code',
#  'fips_name',
#  'discovery_date']

# %%
df_2 = pd.read_csv('nwcg.csv')

# %%
df_full = pd.read_csv('fires.csv', encoding = "ISO-8859-1")

# %%
df_full = df_full.drop('Shape', axis =1)

# %%
columns = df_full.columns

# %%
new_cols = [col.lower() for col in columns]

# %%
db.insert(df_full, 'fires', if_exists='append', index=False, chunksize=1000)
# Out:
# 2019-11-06 15:40:29,717 - INFO - db_utils.py @122 : insert() - Inserting dataframe into `fires`...
# 2019-11-06 15:40:30,914 - DEBUG - db_utils.py @123 : insert() - Data:
#          objectid     fod_id             fpa_id source_system_type  \
# 0               1          1         FS-1418826                FED
# 1               2          2         FS-1418827                FED
# 2               3          3         FS-1418835                FED
# 3               4          4         FS-1418845                FED
# 4               5          5         FS-1418847                FED
# 5               6          6         FS-1418849                FED
# 6               7          7         FS-1418851                FED
# 7               8          8         FS-1418854                FED
# 8               9          9         FS-1418856                FED
# 9              10         10         FS-1418859                FED
# ...

# %%
df_full
# Out:
#          objectid     fod_id             fpa_id source_system_type  \
# 0               1          1         FS-1418826                FED
# 1               2          2         FS-1418827                FED
# 2               3          3         FS-1418835                FED
# 3               4          4         FS-1418845                FED
# 4               5          5         FS-1418847                FED
# 5               6          6         FS-1418849                FED
# 6               7          7         FS-1418851                FED
# 7               8          8         FS-1418854                FED
# 8               9          9         FS-1418856                FED
# 9              10         10         FS-1418859                FED
# 10             11         11         FS-1418861                FED
# 11             12         12         FS-1418863                FED
# 12             13         13         FS-1418865                FED
# ...

# %%
nwcg = pd.read_csv('nwcg.csv')

# %%
nwcg
# Out:
#       OBJECTID    UNITID GEO_AREA     GACC                 WILDLAND_AREA  \
# 0            1   USAKCAN       AK  USAKACC        Resource Provider Only
# 1            2  USAKCEKX       AK  USAKACC      Incident Host Geographic
# 2            3  USAKCFFX       AK  USAKACC      Incident Host Geographic
# 3            4  USAKCFMX       AK  USAKACC      Incident Host Geographic
# 4            5   USAKCFQ       AK  USAKACC      Incident Host Geographic
# 5            6   USAKCGF       AK  USAKACC      Incident Host Geographic
# 6            7  USAKCGFC       AK  USAKACC  Dispatch/Coordination Center
# 7            8  USAKCGFX       AK  USAKACC      Incident Host Geographic
# 8            9  USAKCGKX       AK  USAKACC      Incident Host Geographic
# 9           10  USAKCGMX       AK  USAKACC      Incident Host Geographic
# 10          11  USAKCHCX       AK  USAKACC      Incident Host Geographic
# 11          12   USAKCHN       AK  USAKACC        Resource Provider Only
# ...

# %%
columns = nwcg.columns

# %%
table_builder(columns)
# Out:
# OBJECTID TEXT NULL, UNITID TEXT NULL, GEO_AREA TEXT NULL, GACC TEXT NULL, WILDLAND_AREA TEXT NULL, UNIT_TYPE TEXT NULL, DEPARTMENT TEXT NULL, AGENCY TEXT NULL, PARENT TEXT NULL, COUNTRY TEXT NULL, STATE TEXT NULL, CODE TEXT NULL, NAME TEXT NULL,

# %%
db.insert(nwcg, 'nwcg', index=False, if_exists='append', chunksize=1000)
# Out:
# 2019-11-06 16:49:03,697 - INFO - db_utils.py @122 : insert() - Inserting dataframe into `nwcg`...
# 2019-11-06 16:49:03,717 - DEBUG - db_utils.py @123 : insert() - Data:
#       OBJECTID    UNITID GEO_AREA     GACC                 WILDLAND_AREA  \
# 0            1   USAKCAN       AK  USAKACC        Resource Provider Only
# 1            2  USAKCEKX       AK  USAKACC      Incident Host Geographic
# 2            3  USAKCFFX       AK  USAKACC      Incident Host Geographic
# 3            4  USAKCFMX       AK  USAKACC      Incident Host Geographic
# 4            5   USAKCFQ       AK  USAKACC      Incident Host Geographic
# 5            6   USAKCGF       AK  USAKACC      Incident Host Geographic
# 6            7  USAKCGFC       AK  USAKACC  Dispatch/Coordination Center
# 7            8  USAKCGFX       AK  USAKACC      Incident Host Geographic
# 8            9  USAKCGKX       AK  USAKACC      Incident Host Geographic
# 9           10  USAKCGMX       AK  USAKACC      Incident Host Geographic
# ...

# %%
df_full.columns
# Out:
# Index(['objectid', 'fod_id', 'fpa_id', 'source_system_type', 'source_system',
#        'nwcg_reporting_agency', 'nwcg_reporting_unit_id',
#        'nwcg_reporting_unit_name', 'source_reporting_unit',
#        'source_reporting_unit_name', 'local_fire_report_id',
#        'local_incident_id', 'fire_code', 'fire_name',
#        'ics_209_incident_number', 'ics_209_name', 'mtbs_id', 'mtbs_fire_name',
#        'complex_name', 'fire_year', 'discovery_date', 'discovery_doy',
#        'discovery_time', 'stat_cause_code', 'stat_cause_descr', 'cont_date',
#        'cont_doy', 'cont_time', 'fire_size', 'fire_size_class', 'latitude',
#        'longitude', 'owner_code', 'owner_descr', 'state', 'county',
#        'fips_code', 'fips_name'],
#       dtype='object')

# %%
df_full.shape
# Out:
# (1880465, 38)
